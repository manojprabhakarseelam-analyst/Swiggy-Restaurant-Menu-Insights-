# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_excel((r"C:\Users\S.Manoj Prabhakar\OneDrive\Documents\Book1.xlsx"))
df.head()
# Out:
#        State       City           Restaurant Name              Location  \
# 0  Karnataka  Bengaluru  Anand Sweets & Savouries  Rajarajeshwari Nagar
# 1  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 2  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 3  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
# 4  Karnataka  Bengaluru     Srinidhi Sagar Deluxe               Kengeri
#
#       Category             Dish Name  Price (INR)  Rating  Rating Count
# 0        Snack  Butter Murukku-200gm        133.9     0.0           0.0
# 1  Recommended            Badam Milk         52.0     4.5          25.0
# 2  Recommended        Chow Chow Bath        117.0     4.7          48.0
# 3  Recommended           Kesari Bath         65.0     4.6          65.0
# 4  Recommended            Mix Raitha        130.0     0.0           0.0

# %%
df.shape
# Out:
# (191344, 9)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 191344 entries, 0 to 191343
# Data columns (total 9 columns):
#  #   Column           Non-Null Count   Dtype
# ---  ------           --------------   -----
#  0   State            191343 non-null  object
#  1   City             191310 non-null  object
#  2   Restaurant Name  191310 non-null  object
#  3   Location         191310 non-null  object
#  4   Category         191285 non-null  object
#  5   Dish Name        191285 non-null  object
#  6   Price (INR)      191245 non-null  float64
#  7   Rating           191245 non-null  float64
#  8   Rating Count     191245 non-null  float64
# dtypes: float64(3), object(6)
# memory usage: 13.1+ MB

# %%
df.describe()
# Out:
#          Price (INR)         Rating   Rating Count
# count  191245.000000  191245.000000  191245.000000
# mean      268.016005       2.608059      28.454088
# std       218.571396       2.146285      88.044915
# min         0.950000       0.000000       0.000000
# 25%       139.000000       0.000000       0.000000
# 50%       229.000000       3.900000       2.000000
# 75%       329.000000       4.500000      15.000000
# max      8000.000000       5.000000     999.000000

# %%
top_restaurants = df['Restaurant Name'].value_counts().head(10)
print(top_restaurants)
# Out:
# Restaurant Name
# McDonald's                             12833
# KFC                                    12203
# Burger King                             6545
# Pizza Hut                               6353
# Domino's Pizza                          5326
# LunchBox - Meals and Thalis             4492
# Baskin Robbins - Ice Cream Desserts     4032
# Faasos - Wraps, Rolls & Shawarma        3112
# Olio - The Wood Fired Pizzeria          2973
# The Good Bowl                           2575
# Name: count, dtype: int64

# %%
top_categories = df['Category'].value_counts().head(10)

top_categories.plot(kind='bar')
plt.title("Top 10 Category Distribution")
plt.xticks(rotation=45)
plt.show()

# %%
df.groupby('City')['Restaurant Name'].nunique().sort_values(ascending=False)
# Out:
# City
# Jaipur         91
# Bengaluru      88
# Chandigarh     80
# Lucknow        77
# Kolkata        77
# Hyderabad      77
# New Delhi      71
# Mumbai         71
# Chennai        70
# Imphal         66
# Srinagar       61
# Ahmedabad      60
# Guwahati       58
# Patna          56
# Bhubaneswar    55
# Agartala       53
# Kochi          50
# Indore         49
# Dehradun       48
# Ranchi         45
# Gurgaon        44
# Raipur         43
# Panaji         42
# Shimla         42
# Aizawl         35
# Shillong       34
# Kohima         30
# Gangtok        25
# 450             2
# 410             1
# 400             1
# 430             1
# 435             1
# 440             1
# 651             1
# 485             1
# 653             1
# 621             1
# 640             1
# 390             1
# 900             1
# 800             1
# 799             1
# 715             1
# 704             1
# 690             1
# 688             1
# 678             1
# 350             1
# ...

# %%
df['Location'].value_counts().head(10)
# Out:
# Location
# Gomti Nagar      2054
# Nerul            2034
# Yelahanka        1990
# Police Bazar     1814
# Vasant Kunj      1789
# Whitefield       1727
# Thane West       1711
# Jagatpura        1662
# Gangtok          1544
# Shankar Nagar    1460
# Name: count, dtype: int64
